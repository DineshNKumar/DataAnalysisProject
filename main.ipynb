# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os

# %%
files = os.listdir("Sales_Data/")
files
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
all_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('Sales_Data/'+file)
    all_data = pd.concat([all_data, df])

all_data.to_csv('all.csv')

# %%
data = pd.read_csv('all.csv')
data.shape
# Out:
# (186850, 7)

# %%
data = data.dropna()
data
# Out:
#         Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0                0   176558        USB-C Charging Cable                2
# 2                2   176559  Bose SoundSport Headphones                1
# 3                3   176560                Google Phone                1
# 4                4   176560            Wired Headphones                1
# 5                5   176561            Wired Headphones                1
# ...            ...      ...                         ...              ...
# 186845       11681   259353      AAA Batteries (4-pack)                3
# 186846       11682   259354                      iPhone                1
# 186847       11683   259355                      iPhone                1
# 186848       11684   259356      34in Ultrawide Monitor                1
# 186849       11685   259357        USB-C Charging Cable                1
#
#        Price Each      Order Date                         Purchase Address
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                2
# 2           2   176559  Bose SoundSport Headphones                1
# 3           3   176560                Google Phone                1
# 4           4   176560            Wired Headphones                1
# 5           5   176561            Wired Headphones                1
#
#   Price Each      Order Date                      Purchase Address
# 0      11.95  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2      99.99  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3        600  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4      11.99  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5      11.99  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
data['Month'] = data['Order Date'].str[0:2]
data['Month']
# Out:
# 0         04
# 2         04
# 3         04
# 4         04
# 5         04
#           ..
# 186845    09
# 186846    09
# 186847    09
# 186848    09
# 186849    09
# Name: Month, Length: 186305, dtype: object

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Order ID', 'Product', 'Quantity Ordered', 'Price Each',
#        'Order Date', 'Purchase Address', 'Month'],
#       dtype='object')

# %%
data.Month = data['Month'].loc[data['Month'] != 'Or']
data
# Out:
#         Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0                0   176558        USB-C Charging Cable                2
# 2                2   176559  Bose SoundSport Headphones                1
# 3                3   176560                Google Phone                1
# 4                4   176560            Wired Headphones                1
# 5                5   176561            Wired Headphones                1
# ...            ...      ...                         ...              ...
# 186845       11681   259353      AAA Batteries (4-pack)                3
# 186846       11682   259354                      iPhone                1
# 186847       11683   259355                      iPhone                1
# 186848       11684   259356      34in Ultrawide Monitor                1
# 186849       11685   259357        USB-C Charging Cable                1
#
#        Price Each      Order Date                         Purchase Address  \
# ...

# %%
data = data.dropna()
data['Month'] = pd.to_numeric(data['Month'])
data.Month.dtype
# Out:
# <ipython-input-10-a7b273eaf73c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Month'] = pd.to_numeric(data['Month'])
# dtype('int64')

# %%
data.head()
# Out:
#    Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                2
# 2           2   176559  Bose SoundSport Headphones                1
# 3           3   176560                Google Phone                1
# 4           4   176560            Wired Headphones                1
# 5           5   176561            Wired Headphones                1
#
#   Price Each      Order Date                      Purchase Address  Month
# 0      11.95  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2      99.99  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3        600  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4      11.99  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5      11.99  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %%
data['Quantity Ordered'] = data['Quantity Ordered'].astype('int32')
data['Price Each'] = data['Price Each'].astype('float32')
# Out:
# <ipython-input-12-d19cb31a51b5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Quantity Ordered'] = data['Quantity Ordered'].astype('int32')
# <ipython-input-12-d19cb31a51b5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Price Each'] = data['Price Each'].astype('float32')

# %%
data['Sales'] = data['Quantity Ordered'] * data['Price Each']
data.head()
# Out:
# <ipython-input-13-ca7614748e09>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Sales'] = data['Quantity Ordered'] * data['Price Each']
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each      Order Date                      Purchase Address  Month  \
# 0   11.950000  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each      Order Date                      Purchase Address  Month  \
# 0   11.950000  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2   99.989998  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  600.000000  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4   11.990000  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5   11.990000  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#         Sales
# 0   23.900000
# 2   99.989998
# 3  600.000000
# 4   11.990000
# 5   11.990000

# %%
data.Sales.dtype
# Out:
# dtype('float64')

# %%
s = data.groupby(['Month']).sum()

# %%
months = range(1,13)
plt.bar(months, s['Sales'])
plt.xticks(months)

plt.xlabel('Months')
plt.ylabel('US Dollar')

plt.show()

# %%
# QUESTION 2 : What city had the highest number of sales

# %%
data.groupby('Purchase Address')

# %%
data['City'] = data['Purchase Address'].apply(lambda x : x.split(',')[1])
# Out:
# <ipython-input-20-98128bcd216f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['City'] = data['Purchase Address'].apply(lambda x : x.split(',')[1])

# %%
sales = data.groupby('City').sum()

# %%
sales
# Out:
#                 Unnamed: 0  Quantity Ordered   Price Each   Month  \
# City
#  Atlanta         122928154             16602  2779908.250  104794
#  Austin           82709457             11153  1809873.625   69829
#  Boston          165758780             22528  3637409.750  141112
#  Dallas          124308328             16730  2752627.750  104620
#  Los Angeles     247743297             33289  5421435.000  208325
#  New York City   208439450             27932  4635371.000  175741
#  Portland        104043698             14053  2307747.500   87765
#  San Francisco   372569180             50239  8211461.500  315520
#  Seattle         122394893             16553  2733296.000  104941
#
#                        Sales
# City
#  Atlanta        2.795499e+06
#  Austin         1.819582e+06
#  Boston         3.661642e+06
#  Dallas         2.767975e+06
#  Los Angeles    5.452571e+06
#  New York City  4.664317e+06
#  Portland       2.320491e+06
#  San Francisco  8.262204e+06
# ...

# %%
months = sales['Month']
values = list(months.values)
city = list(months.index)

plt.barh(city, values)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
months = sales['Sales']
values = list(months.values)
city = list(months.index)

plt.barh(city, values)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# WHAT IS THE BEST MONTH FOR SALES
s
# Out:
#        Unnamed: 0  Quantity Ordered   Price Each         Sales
# Month
# 1        47433245             10903  1811768.375  1.822257e+06
# 2        72123197             13449  2188884.750  2.202022e+06
# 3       115333587             17005  2791207.750  2.807100e+06
# 4       167977608             20558  3367671.000  3.390670e+06
# 5       137829259             18667  3135125.000  3.152607e+06
# 6        92330356             15253  2562025.500  2.577802e+06
# 7       102752005             16072  2632539.500  2.647776e+06
# 8        71824951             13448  2230345.500  2.244468e+06
# 9        67863032             13109  2084992.125  2.097560e+06
# 10      206528743             22703  3715554.750  3.736727e+06
# 11      155210546             19798  3180600.750  3.199603e+06
# 12      313688708             28114  4588415.500  4.613443e+06

# %%
sales = s.Sales
# print(sales)
m = list(sales.index)
# print(m)
sales = sales.values
# print(sales)
plt.barh(m, sales)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each      Order Date                      Purchase Address  Month  \
# 0   11.950000  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2   99.989998  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  600.000000  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4   11.990000  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5   11.990000  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#         Sales          City
# 0   23.900000        Dallas
# 2   99.989998        Boston
# ...

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])
# Out:
# <ipython-input-28-da88abbd144d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Order Date'] = pd.to_datetime(data['Order Date'])

# %%
data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each          Order Date                      Purchase Address  \
# 0   11.950000 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2   99.989998 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3  600.000000 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4   11.990000 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5   11.990000 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001
#
#    Month       Sales          City
# 0      4   23.900000        Dallas
# 2      4   99.989998        Boston
# ...

# %%
data['Hour'] = data['Order Date'].dt.hour
data['Minute'] = data['Order Date'].dt.minute

data.head()
# Out:
# <ipython-input-30-9c35e148a295>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Hour'] = data['Order Date'].dt.hour
# <ipython-input-30-9c35e148a295>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Minute'] = data['Order Date'].dt.minute
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# ...

# %%
hours = [hour for hour, df in data.groupby(['Hour'])]
plt.plot(hours, data.groupby(['Hour']).count())
plt.grid()
plt.xlabel('Hours')
plt.ylabel('Sale')
plt.xticks(hours)
plt.show()

# %%
# What products are sold moslty together

# %%
data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each          Order Date                      Purchase Address  \
# 0   11.950000 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2   99.989998 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3  600.000000 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4   11.990000 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5   11.990000 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001
#
#    Month       Sales          City  Hour  Minute
# 0      4   23.900000        Dallas     8      46
# ...

# %%
data.groupby(['Product']).sum()
# Out:
#                             Unnamed: 0  Quantity Ordered    Price Each  \
# Product
# 20in Monitor                  34263700              4129  4.510690e+05
# 27in 4K Gaming Monitor        52531482              6244  2.429638e+06
# 27in FHD Monitor              62800951              7550  1.125975e+06
# 34in Ultrawide Monitor        51318688              6199  2.348718e+06
# AA Batteries (4-pack)        170984790             27635  7.901568e+04
# AAA Batteries (4-pack)       171339939             31017  6.171659e+04
# Apple Airpods Headphones     129879472             15661  2.332350e+06
# Bose SoundSport Headphones   111875345             13457  1.332367e+06
# Flatscreen TV                 39883719              4819  1.440000e+06
# Google Phone                  45223404              5532  3.315000e+06
# LG Dryer                       5507786               646  3.876000e+05
# LG Washing Machine             5284208               666  3.996000e+05
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each          Order Date                      Purchase Address  \
# 0   11.950000 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2   99.989998 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3  600.000000 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4   11.990000 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5   11.990000 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001
#
#    Month       Sales          City  Hour  Minute
# 0      4   23.900000        Dallas     8      46
# ...

# %% [markdown]
# # What product sold mostly

# %%
data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each          Order Date                      Purchase Address  \
# 0   11.950000 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2   99.989998 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3  600.000000 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4   11.990000 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5   11.990000 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001
#
#    Month       Sales          City  Hour  Minute
# 0      4   23.900000        Dallas     8      46
# ...

# %%
df = data[data['Order ID'].duplicated(keep=False)]

df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

df.head()
# Out:
# <ipython-input-43-90ef9f997c0a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#     Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 3            3   176560                Google Phone                 1
# 4            4   176560            Wired Headphones                 1
# 18          18   176574                Google Phone                 1
# 19          19   176574        USB-C Charging Cable                 1
# 30          30   176585  Bose SoundSport Headphones                 1
#
#     Price Each          Order Date                      Purchase Address  \
# ...

# %%
df = df[['Order ID', 'Grouped']].drop_duplicates()
df.head(20)
# Out:
#     Order ID                                            Grouped
# 3     176560                      Google Phone,Wired Headphones
# 18    176574                  Google Phone,USB-C Charging Cable
# 30    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32    176586                AAA Batteries (4-pack),Google Phone
# 119   176672      Lightning Charging Cable,USB-C Charging Cable
# 129   176681           Apple Airpods Headphones,ThinkPad Laptop
# 138   176689  Bose SoundSport Headphones,AAA Batteries (4-pack)
# 189   176739                34in Ultrawide Monitor,Google Phone
# 225   176774      Lightning Charging Cable,USB-C Charging Cable
# 233   176781                    iPhone,Lightning Charging Cable
# 250   176797  Google Phone,Bose SoundSport Headphones,Wired ...
# 260   176805                  Google Phone,USB-C Charging Cable
# 264   176808                      Google Phone,Wired Headphones
# 270   176813                      Google Phone,Wired Headphones
# ...

# %%
from itertools import combinations
from collections import Counter

# %%
count = Counter()

for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

count.most_common(10)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005),
#  (('Google Phone', 'USB-C Charging Cable'), 987),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 414),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 160),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %%
all_d = count.most_common(20)

key = []
value = []

for k in all_d:
    key.append(k[0][0])
    value.append(k[1])
    

plt.bar(key, value)
plt.xticks(rotation='vertical')

plt.show()

# %% [markdown]
# # High sale of product

# %%
product_group = data.groupby('Product')
quantity_group = product_group.sum()['Quantity Ordered']

products = [product for product, df in product_group]

plt.bar(products, quantity_group)
plt.xticks(products, rotation='vertical')
plt.xlabel('Product')
plt.ylabel('Quantity Ordered')

plt.show()

# %%
prices = data.groupby('Product').mean()['Price Each']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()

ax1.bar(products, quantity_group, color='green')
ax2.plot(products, prices)

ax1.set_xticklabels(products,rotation='vertical')

plt.show()
# Out:
# <ipython-input-88-ef7a008797cc>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products,rotation='vertical')
